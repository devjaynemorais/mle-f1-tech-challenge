# %% [markdown]
# # Notebook 04 — Modelo MVP
#
# Seleção e avaliação final do modelo MVP.
#
# **Objetivo:** documentar a escolha do modelo campeão com base nos experimentos, avaliar performance final e registrar no MLflow.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path().resolve().parent))
import yaml

with open('../config/config.yaml') as f:
    config = yaml.safe_load(f)

print(f"Modelo de producao: {config['model']['name']}")
print(f"Artefato: {config['model']['model_path']}")
