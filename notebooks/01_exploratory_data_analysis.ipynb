# %% [markdown]
# # Exploratory Data Analysis
# ## Dataset: Telco Customer Churn

# %%
import pandas as pd

# O dataset no Kaggle geralmente se chama Telco-Customer-Churn.csv
df = pd.read_csv('../data/Telco-Customer-Churn.csv')
df.head()

# %% [markdown]
# ### Dataset Info

# %%
df.info()

# %% [markdown]
# ### Dataset Description

# %%
df.describe(include='all')
